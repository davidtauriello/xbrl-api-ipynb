# %% [markdown]
# ## Running XULE - Python example
# This sample Python code runs Arelle and the XULE plugin in a virtual environment.

# %%
import os, sys
# !{sys.executable} -m pip install aniso8601
# !{sys.executable} -m pip install pyparsing
# !{sys.executable} -m pip install git+https://github.com/Arelle/Arelle
# %cd /srv/conda/envs/notebook/lib/python3.9/site-packages/arelle/
# !python CntlrCmdLine.py -a

# %%
# %%bash
# set -x
# svn export --force --quiet https://github.com/xbrlus/xule/trunk/plugin/xule /srv/conda/envs/notebook/lib/python3.9/site-packages/arelle/plugin/xule

# %%
# %run CntlrCmdLine.py --plugins 'xule' -v
# %run CntlrCmdLine.py --plugins 'xule' -h

# %%
# %run CntlrCmdLine.py --plugins 'xule | transforms/SEC' -f 'https://www.sec.gov/Archives/edgar/data/1753673/000121390022027184/f20f2021_scienjoyhold.htm' --httpUserAgent "XULE-Arelle (xbrl.us; support@xbrl.us)" --xule-compile 'sample.xule' --xule-run --xule-rule-set 'sample.zip'
