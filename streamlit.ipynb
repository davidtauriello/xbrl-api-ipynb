# %%
! pip install streamlit -q
! pip install xbrl-us -q
! npm install localtunnel
import streamlit as st
import yaml

# %%
# !wget -q -O - ipv4.icanhazip.com
# !python -m xbrl_us & npx localtunnel --port 8501
