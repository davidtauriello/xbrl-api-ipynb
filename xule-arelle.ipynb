# %% [markdown]
# ## Running XULE - Python example
# This sample Python code runs Arelle and the XULE plugin in a virtual environment.

# %%
import os, sys, shutil
from IPython.display import display, HTML
# !{sys.executable} -m pip install git+https://github.com/Arelle/Arelle
# %cd /srv/conda/envs/notebook/lib/python3.9/site-packages/arelle/

# %%
# %%bash
# git clone https://github.com/xbrlus/xule

# %%
source_dir = '/srv/conda/envs/notebook/lib/python3.9/site-packages/arelle/xule/plugin/xule'
target_dir = '/srv/conda/envs/notebook/lib/python3.9/site-packages/arelle/plugin/xule'
    
file_names = os.listdir(source_dir)
    
for file_name in file_names:
    shutil.move(os.path.join(source_dir, file_name), target_dir)

os.rmdir(source_dir)

# !python CntlrCmdLine.py -a

# !python CntlrCmdLine.py --httpUserAgent "XUS-Arelle (xbrl.us; xule@xbrl.us)" --plugins "transforms/SEC" -f "https://www.sec.gov/Archives/edgar/data/1753673/000121390022027184/f20f2021_scienjoyhold.htm"
