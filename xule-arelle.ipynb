# %% [markdown]
# ## Running XULE - Python example
# This sample Python code runs Arelle and the XULE plugin in a virtual environment.

# %%
import os, re, sys, json
import requests
import pandas as pd
from IPython.display import display, HTML
import numpy as np
# !{sys.executable} -m pip install arelle
cwd = os.getcwd()
print("Initial working directory: {0}".format(cwd))

# %cd /srv/conda/envs/notebook/lib/python3.9/site-packages/arelle
# Out:
# Requirement already satisfied: arelle in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (2.2)
# Initial working directory: d:\DJT\Documents\GitHub\davidtauriello\xbrl-api-ipynb
# Arelle directory: d:\DJT\Documents\GitHub\davidtauriello\xbrl-api-ipynb
# [WinError 3] The system cannot find the path specified: '/srv/conda/envs/notebook/lib/python3.9/site-packages/arelle'
# d:\DJT\Documents\GitHub\davidtauriello\xbrl-api-ipynb
# WARNING: You are using pip version 21.1.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\David\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
